# %%
import requests
import pandas as pd
from datetime import date, timedelta
from urllib.parse import quote_plus

# %% [markdown]
# ### Configuration

# %%
# Organizations
ORG_CANDIDATES = [
    "Corewell Health",
    "Spectrum Health",
    "Beaumont Health",
]

# Columns you asked for (final, normalized)
OUT_COLS = [
    "id","agency","awardeeName","awardeeCity","awardeeStateCode",
    "piFirstName","piLastName","title","date","startDate","expDate",
    "fundsObligatedAmt","abstractText"
]

# Last 3 years (inclusive) based on today's date
TODAY = date.today()
START = TODAY.replace(year=TODAY.year - 20)

# %% [markdown]
# ### NSF Data Extraction

# %%
def fetch_nsf_awards(org_names, start_date, end_date):
    base = "https://api.nsf.gov/services/v1/awards.json"
    s = start_date.strftime("%m/%d/%Y")
    e = end_date.strftime("%m/%d/%Y")
    rpp = 25

    rows = []
    for org in org_names:
        offset = 1
        while True:
            params = {
                "awardeeName": org,
                "startDateStart": s,
                "startDateEnd": e,
                "rpp": rpp,
                "offset": offset,
                "printFields": ",".join([
                    "id","agency","awardeeName","awardeeCity","awardeeStateCode",
                    "pdPIName","piFirstName","piLastName","title","date","startDate","expDate",
                    "fundsObligatedAmt","abstractText"
                ])
            }
            resp = requests.get(base, params=params, timeout=60)
            resp.raise_for_status()
            data = resp.json()
            awards = (data.get("response") or {}).get("award") or []
            if not awards:
                break

            for a in awards:
                pi_first = a.get("piFirstName")
                pi_last = a.get("piLastName")
                if (not pi_first or not pi_last) and a.get("pdPIName"):
                    parts = a["pdPIName"].split()
                    if len(parts) >= 2:
                        pi_first = pi_first or parts[0]
                        pi_last = pi_last or " ".join(parts[1:])

                rows.append({
                    "id": str(a.get("id") or ""),
                    "agency": a.get("agency") or "NSF",
                    "awardeeName": a.get("awardeeName") or org,
                    "awardeeCity": a.get("awardeeCity"),
                    "awardeeStateCode": a.get("awardeeStateCode"),
                    "piFirstName": pi_first,
                    "piLastName": pi_last,
                    "title": a.get("title"),
                    "date": a.get("date"),
                    "startDate": a.get("startDate"),
                    "expDate": a.get("expDate"),
                    "fundsObligatedAmt": a.get("fundsObligatedAmt"),
                    "abstractText": a.get("abstractText"),
                    "orgCandidate": org    # <--- new column
                })

            if len(awards) < rpp:
                break
            offset += rpp

    df = pd.DataFrame(rows)
    return df

# %%
nsf_df_org= fetch_nsf_awards(ORG_CANDIDATES, START, TODAY)

# %%
nsf_df_org
# Out:
#            id agency                                        awardeeName  \
# 0     2432754    NSF                                     XN HEALTH INC.
# 1     2505338    NSF                 Oregon Health & Science University
# 2     2451412    NSF                           ABSTRACTIVE HEALTH, INC.
# 3     2419342    NSF                           INSU HEALTH DESIGN, INC.
# 4     2444410    NSF  University of North Texas Health Science Cente...
# ...       ...    ...                                                ...
# 1510  0525026    NSF  University of Texas Health Science Center San ...
# 1511  0534797    NSF                 Oregon Health & Science University
# 1512  0635493    NSF                 Oregon Health & Science University
# 1513  0513492    NSF                 Oregon Health & Science University
# 1514  0524835    NSF                 Oregon Health & Science University
#
#       awardeeCity awardeeStateCode piFirstName  piLastName  \
# 0          NEWARK               NJ   Elizabeth    Jaworski
# 1        PORTLAND               OR        Paul    Tratnyek
# 2        NEW YORK               NY       Vince     Hartman
# 3        MAYAGUEZ               PR       Mason      Lucich
# 4      FORT WORTH               TX      Austin    Reynolds
# ...           ...              ...         ...         ...
# 1510  SAN ANTONIO               TX       DAVID  KATERNDAHL
# 1511     PORTLAND               OR        Paul      Gorman
# 1512     PORTLAND               OR     Bradley        Tebo
# 1513     PORTLAND               OR       James      Pankow
# 1514     PORTLAND               OR       Deniz    Erdogmus
#
#                                                   title        date  \
# 0     STTR Phase I:  Tracheal Phrenic Nerve Stimulat...  07/11/2025
# 1     Electrochemical Characterization of Redox Proc...  05/22/2025
# 2     SBIR Phase II : A tool to automate a narrative...  07/01/2025
# 3     SBIR Phase II: Insu Health Design: Temperature...  05/15/2025
# 4     Collaborative Research: Genomic and Isotopic A...  04/07/2025
# ...                                                 ...         ...
# 1510          Dynamic Patterns of Husband-to-Wife Abuse  12/12/2005
# 1511  Collaborative Research: Supporting Rapid Trans...  10/19/2005
# 1512  Bacterial Manganese (II) Oxidation in the Guay...  06/16/2006
# 1513  Thermodynamic Modeling of Atmospheric Organic ...  09/20/2005
# 1514  Robust Information Filtering Techniques for St...  08/29/2005
#
#        startDate     expDate fundsObligatedAmt  \
# 0     07/15/2025  06/30/2026            274841
# 1     07/01/2025  06/30/2028            410000
# 2     07/01/2025  06/30/2027           1250000
# 3     05/15/2025  04/30/2027            998527
# 4     04/15/2025  03/31/2028             63318
# ...          ...         ...               ...
# 1510  12/15/2005  11/30/2007            124214
# 1511  11/01/2005  10/31/2009            192037
# 1512  10/01/2005  03/31/2008            185289
# 1513  10/01/2005  04/30/2009            424999
# 1514  10/01/2005  05/31/2009            239998
#
#                                            abstractText     orgCandidate
# 0     The broader/commercial impact of this Small Bu...  Corewell Health
# 1     With support from the Environmental Chemical S...  Corewell Health
# 2     The broader impact/commercial potential of thi...  Corewell Health
# 3     This Small Business Innovation Research (SBIR)...  Corewell Health
# 4     Studies of human population genetics can revea...  Corewell Health
# ...                                                 ...              ...
# 1510  This exploratory research study will evaluate ...  Beaumont Health
# 1511  This is a project to understand essential issu...  Beaumont Health
# 1512  ABSTRACT  OCE- 0352081    Hydrothermal vents a...  Beaumont Health
# 1513  This project involves the further development ...  Beaumont Health
# 1514  Proposal Number: ECS-0524835    Proposal Title...  Beaumont Health
#
# [1515 rows x 14 columns]

# %% [markdown]
# ### NIH Data  Extraction

# %%
def fetch_nih_awards(org_names, start_date, end_date):
    """
    Fetch awards from NIH RePORTER v2 Projects API for given organizations and date range.
    Normalizes to OUT_COLS schema.
    """
    url = "https://api.reporter.nih.gov/v2/projects/search"
    rows = []

    # RePORTER supports posting arrays of org names and a date range filter.
    # We'll query per-org to keep results tidy and easy to troubleshoot.
    for org in org_names:
        offset = 0
        page_size = 500  # RePORTER allows large page sizes

        while True:
            payload = {
                "criteria": {
                    "org_names": [org],
                    # Use Notice of Award date to approximate "date"; you can switch to project_start_date if preferred
                    "award_notice_date": {
                        "from_date": start_date.strftime("%Y-%m-%d"),
                        "to_date": end_date.strftime("%Y-%m-%d")
                    }
                },
                "include_fields": [
                    "ApplId",
                    "Organization",            # includes name, city, state, etc.
                    "PrincipalInvestigators",  # includes first_name, last_name
                    "ProjectTitle",
                    "AwardNoticeDate",         # maps to our 'date'
                    "ProjectStartDate",
                    "ProjectEndDate",
                    "AwardAmount",             # we'll map to fundsObligatedAmt
                    "AbstractText"
                ],
                "offset": offset,
                "limit": page_size
            }

            resp = requests.post(url, json=payload, timeout=90)
            resp.raise_for_status()
            data = resp.json()

            results = data.get("results") or []
            if not results:
                break

            for r in results:
                org_obj = r.get("organization") or {}
                pis = r.get("principal_investigators") or []
                # Take the first PI if present
                pi_first = pi_last = None
                if pis:
                    pi_first = pis[0].get("first_name")
                    pi_last = pis[0].get("last_name")

                rows.append({
                    "id": str(r.get("appl_id") or ""),
                    "agency": "NIH",
                    "awardeeName": org_obj.get("org_name") or org,
                    "awardeeCity": org_obj.get("org_city"),
                    "awardeeStateCode": org_obj.get("org_state"),
                    "piFirstName": pi_first,
                    "piLastName": pi_last,
                    "title": r.get("project_title"),
                    "date": r.get("award_notice_date"),   # yyyy-mm-dd
                    "startDate": r.get("project_start_date"),
                    "expDate": r.get("project_end_date"),
                    "fundsObligatedAmt": r.get("award_amount"),  # normalized name
                    "abstractText": r.get("abstract_text"),
                })

            offset += page_size
            if offset >= (data.get("meta", {}).get("total") or 0):
                break

    df = pd.DataFrame(rows, columns=OUT_COLS)
    return df

# %%
fetch_nih_awards(ORG_CANDIDATES, START, TODAY)
# Out:
#           id agency                    awardeeName   awardeeCity  \
# 0   11337409    NIH                COREWELL HEALTH  Grand Rapids
# 1   10892231    NIH                COREWELL HEALTH  Grand Rapids
# 2   10675484    NIH                COREWELL HEALTH  Grand Rapids
# 3   10460164    NIH                COREWELL HEALTH  Grand Rapids
# 4   10226962    NIH                COREWELL HEALTH  Grand Rapids
# 5    9991757    NIH                COREWELL HEALTH  Grand Rapids
# 6    9771133    NIH                COREWELL HEALTH  Grand Rapids
# 7    9535231    NIH                COREWELL HEALTH  Grand Rapids
# 8    9330824    NIH                COREWELL HEALTH  Grand Rapids
# 9    9130139    NIH                COREWELL HEALTH  Grand Rapids
# 10   9337964    NIH                COREWELL HEALTH  Grand Rapids
# 11   8798601    NIH                COREWELL HEALTH  Grand Rapids
# 12   8901100    NIH                COREWELL HEALTH  Grand Rapids
# 13   8927724    NIH                COREWELL HEALTH  Grand Rapids
# 14   8854484    NIH                COREWELL HEALTH  Grand Rapids
# 15   8790594    NIH                COREWELL HEALTH  Grand Rapids
# 16   8598075    NIH                COREWELL HEALTH  Grand Rapids
# 17   8637983    NIH                COREWELL HEALTH  Grand Rapids
# 18   8475428    NIH                COREWELL HEALTH  Grand Rapids
# 19   8536107    NIH                COREWELL HEALTH  Grand Rapids
# 20   8659915    NIH                COREWELL HEALTH  Grand Rapids
# 21   8793252    NIH                COREWELL HEALTH  Grand Rapids
# 22   8339309    NIH                COREWELL HEALTH  Grand Rapids
# 23   8294931    NIH                COREWELL HEALTH  Grand Rapids
# 24   8301872    NIH                COREWELL HEALTH  Grand Rapids
# 25   8137237    NIH                COREWELL HEALTH  Grand Rapids
# 26   7890984    NIH                COREWELL HEALTH  Grand Rapids
# 27   7748808    NIH                COREWELL HEALTH  Grand Rapids
# 28   7665077    NIH                COREWELL HEALTH  Grand Rapids
# 29   7473216    NIH                COREWELL HEALTH  Grand Rapids
# 30   7281634    NIH                COREWELL HEALTH  GRAND RAPIDS
# 31   7332940    NIH                COREWELL HEALTH  GRAND RAPIDS
# 32   7082970    NIH                COREWELL HEALTH  GRAND RAPIDS
# 33   8660508    NIH  SPECTRUM HEALTH SYSTEMS, INC.     WORCESTER
#
#    awardeeStateCode piFirstName piLastName  \
# 0                MI    KATHLEEN     BUTLER
# 1                MI    KATHLEEN     BUTLER
# 2                MI    KATHLEEN     BUTLER
# 3                MI    KATHLEEN     BUTLER
# 4                MI    KATHLEEN     BUTLER
# 5                MI    KATHLEEN     BUTLER
# 6                MI    KATHLEEN     BUTLER
# 7                MI    KATHLEEN     BUTLER
# 8                MI    KATHLEEN     BUTLER
# 9                MI    KATHLEEN     BUTLER
# 10               MI    KATHLEEN     BUTLER
# 11               MI      SANDRA     REMPEL
# 12               MI    KATHLEEN     BUTLER
# 13               MI     Gilbert     Padula
# 14               MI     Gilbert     Padula
# 15               MI     Gilbert     Padula
# 16               MI      SANDRA     REMPEL
# 17               MI     KIRSTAN    MELDRUM
# 18               MI     Gilbert     Padula
# 19               MI        Erin      Inman
# 20               MI      SANDRA     REMPEL
# 21               MI     KIRSTAN    MELDRUM
# 22               MI        Erin      Inman
# 23               MI     Gilbert     Padula
# 24               MI        Erin      Inman
# 25               MI     Gilbert     Padula
# 26               MI      Martin       Bury
# 27               MI       Helga   Toriello
# 28               MI      Martin       Bury
# 29               MI      Martin       Bury
# 30               MI    Marianne      Lange
# 31               MI       Helga   Toriello
# 32               MI    Marianne      Lange
# 33               MA       Jason  Montville
#
#                                                 title                 date  \
# 0   Cancer Research Consortium of West Michigan (C...  2025-08-11T00:00:00
# 1   Cancer Research Consortium of West Michigan (C...  2024-07-29T00:00:00
# 2   Cancer Research Consortium of West Michigan (C...  2023-07-20T00:00:00
# 3   Cancer Research Consortium of West Michigan (C...  2022-08-01T00:00:00
# 4   Cancer Research Consortium of West Michigan (C...  2021-07-30T00:00:00
# 5   Cancer Research Consortium of West Michigan (C...  2020-07-31T00:00:00
# 6   Cancer Research Consortium of West Michigan (C...  2019-08-08T00:00:00
# 7   Cancer Research Consortium of West Michigan (C...  2018-07-23T00:00:00
# 8   Cancer Research Consortium of West Michigan (C...  2017-07-27T00:00:00
# 9   Cancer Research Consortium of West Michigan (C...  2016-08-11T00:00:00
# 10  Cancer Research Consortium of West Michigan (C...  2016-08-31T00:00:00
# 11  HSP27: A modulator and therapeutic target of S...  2014-12-24T00:00:00
# 12  Cancer Research Consortium of West Michigan (C...  2015-08-20T00:00:00
# 13  Cancer Research Consortium of West Michigan (C...  2014-09-17T00:00:00
# 14             GRAND RAPIDS CLINICAL ONCOLOGY PROGRAM  2014-05-29T00:00:00
# 15  Cancer Research Consortium of West Michigan (C...  2014-07-31T00:00:00
# 16  HSP27: A modulator and therapeutic target of S...  2014-02-04T00:00:00
# 17  IL-18 Mediates Obstruction-Induced Renal Injur...  2014-05-27T00:00:00
# 18             GRAND RAPIDS CLINICAL ONCOLOGY PROGRAM  2013-06-14T00:00:00
# 19  COMMUNITY TRANSFORMATION GRANT: CAPACITY-BUILD...  2013-09-20T00:00:00
# 20  HSP27: A modulator and therapeutic target of S...  2013-09-18T00:00:00
# 21  IL-18 Mediates Obstruction-Induced Renal Injur...  2014-02-21T00:00:00
# 22  COMMUNITY TRANSFORMATION GRANT: CAPACITY-BUILD...  2012-08-23T00:00:00
# 23             GRAND RAPIDS CLINICAL ONCOLOGY PROGRAM  2012-05-28T00:00:00
# 24  COMMUNITY TRANSFORMATION GRANT: CAPACITY-BUILD...  2011-09-25T00:00:00
# 25             GRAND RAPIDS CLINICAL ONCOLOGY PROGRAM  2011-07-01T00:00:00
# 26             GRAND RAPIDS CLINICAL ONCOLOGY PROGRAM  2010-09-02T00:00:00
# 27  SIXTH INTERNATIONAL NEURAL TUBE DEFECT CONFERENCE  2009-04-30T00:00:00
# 28             GRAND RAPIDS CLINICAL ONCOLOGY PROGRAM  2009-05-14T00:00:00
# 29             GRAND RAPIDS CLINICAL ONCOLOGY PROGRAM  2008-07-24T00:00:00
# 30             GRAND RAPIDS CLINICAL ONCOLOGY PROGRAM  2007-07-18T00:00:00
# 31  5th International Neural Tube Defect Conferenc...  2007-03-30T00:00:00
# 32             GRAND RAPIDS CLINICAL ONCOLOGY PROGRAM  2006-08-24T00:00:00
# 33  OTP EHR Continuity of Care Implementation and ...  2013-06-28T00:00:00
#
#               startDate              expDate  fundsObligatedAmt  \
# 0   2014-08-08T00:00:00  2026-07-31T00:00:00          2724475.0
# 1   2014-08-08T00:00:00  2026-07-31T00:00:00          2153395.0
# 2   2014-08-08T00:00:00  2025-07-31T00:00:00          2113756.0
# 3   2014-08-08T00:00:00  2025-07-31T00:00:00          2190347.0
# 4   2014-08-08T00:00:00  2025-07-31T00:00:00          2184338.0
# 5   2014-08-08T00:00:00  2025-07-31T00:00:00          2302236.0
# 6   2014-08-08T00:00:00  2025-07-31T00:00:00          2372116.0
# 7   2014-08-01T00:00:00  2019-07-31T00:00:00          2751806.0
# 8   2014-08-01T00:00:00  2019-07-31T00:00:00          2341117.0
# 9   2014-08-01T00:00:00  2019-07-31T00:00:00          1580000.0
# 10  2014-08-01T00:00:00  2019-07-31T00:00:00           105006.0
# 11  2011-01-04T00:00:00  2015-12-31T00:00:00           299552.0
# 12  2014-08-01T00:00:00  2019-07-31T00:00:00          1959304.0
# 13  2014-08-01T00:00:00  2019-07-31T00:00:00            50000.0
# 14  1987-06-01T00:00:00  2014-07-31T00:00:00           219652.0
# 15  2014-08-01T00:00:00  2019-07-31T00:00:00          2073804.0
# 16  2011-01-04T00:00:00  2015-12-31T00:00:00           290565.0
# 17  2010-04-01T00:00:00  2017-03-31T00:00:00           318743.0
# 18  1987-06-01T00:00:00  2014-07-31T00:00:00          1417905.0
# 19  2011-09-30T00:00:00  2014-09-29T00:00:00           333321.0
# 20  2011-01-04T00:00:00  2015-12-31T00:00:00           175749.0
# 21  2010-04-01T00:00:00  2015-03-31T00:00:00           259333.0
# 22  2011-09-30T00:00:00  2016-09-29T00:00:00           333321.0
# 23  1987-06-01T00:00:00  2015-05-31T00:00:00          1317905.0
# 24  2011-09-30T00:00:00  2016-09-29T00:00:00           333321.0
# 25  1987-06-01T00:00:00  2015-05-31T00:00:00          1397905.0
# 26  1987-06-01T00:00:00  2015-05-31T00:00:00          1358665.0
# 27  2009-05-01T00:00:00  2010-04-30T00:00:00            20000.0
# 28  1987-06-01T00:00:00  2010-05-31T00:00:00          1278666.0
# 29  1987-06-01T00:00:00  2010-05-31T00:00:00          1198666.0
# 30  1987-06-01T00:00:00  2010-05-31T00:00:00           936039.0
# 31  2007-06-30T00:00:00  2008-06-29T00:00:00            10000.0
# 32  1987-06-01T00:00:00  2010-05-31T00:00:00          1237821.0
# 33  2013-07-01T00:00:00  2014-06-30T00:00:00                NaN
#
#                                          abstractText
# 0   CRCWM Project Summary/Abstract\nThe Cancer Res...
# 1   The Cancer Research Consortium of West Michiga...
# 2   PROJECT SUMMARY\nThe Cancer Research Consortiu...
# 3   PROJECT SUMMARY\nThe Cancer Research Consortiu...
# 4   PROJECT SUMMARY\nThe Cancer Research Consortiu...
# 5   PROJECT SUMMARY\nThe Cancer Research Consortiu...
# 6   PROJECT SUMMARY\nThe Cancer Research Consortiu...
# 7   DESCRIPTION (provided by applicant): The Cance...
# 8   DESCRIPTION (provided by applicant): The Cance...
# 9   DESCRIPTION (provided by applicant): The Cance...
# 10  DESCRIPTION (provided by applicant): The Cance...
# 11  DESCRIPTION (provided by applicant): Glioblast...
# 12  DESCRIPTION (provided by applicant): The Cance...
# 13  DESCRIPTION (provided by applicant): The Cance...
# 14  DESCRIPTION (provided by applicant): The Grand...
# 15     \r\nDESCRIPTION (provided by applicant): Th...
# 16    \nDESCRIPTION (provided by applicant): Gliob...
# 17    \nDESCRIPTION (provided by applicant): Obstr...
# 18  DESCRIPTION (provided by applicant): The Grand...
# 19                                               None
# 20    \nDESCRIPTION (provided by applicant): Gliob...
# 21  DESCRIPTION (provided by applicant): Obstructi...
# 22                                               None
# 23  DESCRIPTION (provided by applicant): The Grand...
# 24                                               None
# 25    \r\nDESCRIPTION (provided by applicant): The...
# 26    \r\nDESCRIPTION (provided by applicant): The...
# 27  OMB Number: 4040-0004\nExpiration Date: 01/31/...
# 28    \r\nDESCRIPTION (provided by applicant):   \...
# 29    \r\nDESCRIPTION (provided by applicant):   \...
# 30    \r\nDESCRIPTION (provided by applicant):   \...
# 31                                               None
# 32    \r\nDESCRIPTION (provided by applicant):   \...
# 33                                               None

# %%
nsf_df_org.to_csv("../Data/NSF_data_20years.csv")

# %%
nsf_df_org.shape
# Out:
# (1515, 14)

# %%
    "project_start_date",
    "project_end_date",
    "abstract_text",
]

def fetch(query):
    """Fetch NIH awards for a given query dict"""
    all_rows = []
    offset = 0
    while True:
        body = {
            "criteria": query,
            "include_fields": FIELDS,
            "offset": offset,
            "limit": 500,  # max NIH allows
        }
        r = requests.post(BASE_URL, json=body, timeout=60)
        r.raise_for_status()
        data = r.json()
        if "results" not in data or not data["results"]:
            break
        all_rows.extend(data["results"])
        offset += 500
        if offset >= data.get("meta", {}).get("total", 0):
            break
    return all_rows

all_rows = []

# 1) Exact org match
for org in ORG_CANDIDATES:
    all_rows += fetch({
        "org_name": org,
        "project_start_date": {"from_date": start_date, "to_date": end_date}
    })

# 2) Keyword fallback search
for org in ORG_CANDIDATES:
    all_rows += fetch({
        "text_search": {"search_text": org},
        "project_start_date": {"from_date": start_date, "to_date": end_date}
    })

# 3) Michigan sweep (state filter)
all_rows += fetch({
    "org_state": "MI",
    "text_search": {"search_text": "Beaumont OR Spectrum OR Corewell"},
    "project_start_date": {"from_date": start_date, "to_date": end_date}
})

df = pd.DataFrame(all_rows).drop_duplicates(subset=["project_num"]) if all_rows else pd.DataFrame()

print(f"Total NIH awards found: {len(df)}")
if df.empty:
    print("No NIH awards matched these org names (last 20 years)import requests, datetime, pandas as pd

BASE_URL = "https://api.reporter.nih.gov/v2/projects/search"

today = datetime.date.today()
start_year = today.year - 20
end_year = today.year

ORG_CANDIDATES = [
    "Corewell Health",
    "Beaumont Health",
    "William Beaumont Hospital",
    "Beaumont Hospital",
    "Spectrum Health",
    "Helen DeVos Children's Hospital",
    "Butterworth Hospital",
    "Lakeland Hospital",
    "Blodgett Hospital",
]

FIELDS = [
    "project_num",
    "project_title",
    "org_name",
    "org_city",
    "org_state",
    "principal_investigators",
    "award_amount",
    "fy",
    "project_start_date",
    "project_end_date",
    "abstract_text",
]

def fetch(query):
    rows = []
    offset = 0
    while True:
        body = {
            "criteria": query,
            "include_fields": FIELDS,
            "offset": offset,
            "limit": 500,
        }
        r = requests.post(BASE_URL, json=body, timeout=60)
        r.raise_for_status()
        data = r.json()
        if "results" not in data or not data["results"]:
            break
        rows.extend(data["results"])
        offset += 500
        if offset >= data.get("meta", {}).get("total", 0):
            break
    return rows

all_rows = []

# Loop over years to avoid offset > 14,999
for year in range(start_year, end_year + 1):
    for org in ORG_CANDIDATES:
        all_rows += fetch({
            "org_name": org,
            "fiscal_years": [year]
        })
        # Keyword fallback
        all_rows += fetch({
            "text_search": {"search_text": org},
            "fiscal_years": [year]
        })
    # Michigan sweep
    all_rows += fetch({
        "org_state": "MI",
        "text_search": {"search_text": "Beaumont OR Spectrum OR Corewell"},
        "fiscal_years": [year]
    })

df = pd.DataFrame(all_rows).drop_duplicates(subset=["project_num"]) if all_rows else pd.DataFrame()

print(f"Total NIH awards found: {len(df)}")
if not df.empty:
    cols = [c for c in ["project_num","project_title","org_name","org_city","org_state","fy","project_start_date"] if c in df.columns]
    print(df[cols].head(25).to_string(index=False))
.")
else:
    cols = [c for c in ["project_num","project_title","org_name","org_city","org_state","fy","project_start_date"] if c in df.columns]
    print(df[cols].head(25).to_string(index=False))
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[11], line 56
#      54 # 1) Exact org match
#      55 for org in ORG_CANDIDATES:
# ---> 56     all_rows += fetch({
#      57         "org_name": org,
#      58         "project_start_date": {"from_date": start_date, "to_date": end_date}
#      59     })
#      61 # 2) Keyword fallback search
#      62 for org in ORG_CANDIDATES:
#
# Cell In[11], line 42, in fetch(query)
#      35 body = {
#      36     "criteria": query,
#      37     "include_fields": FIELDS,
#      38     "offset": offset,
#      39     "limit": 500,  # max NIH allows
#      40 }
#      41 r = requests.post(BASE_URL, json=body, timeout=60)
# ---> 42 r.raise_for_status()
#      43 data = r.json()
#      44 if "results" not in data or not data["results"]:
#
# File c:\Users\roshn\anaconda3\envs\capstone\lib\site-packages\requests\models.py:1026, in Response.raise_for_status(self)
#    1021     http_error_msg = (
#    1022         f"{self.status_code} Server Error: {reason} for url: {self.url}"
#    1023     )
#    1025 if http_error_msg:
# -> 1026     raise HTTPError(http_error_msg, response=self)
#
# HTTPError: 400 Client Error: System doesn't support offset value greater than 14,999. Please narrow down your search criteria. for url: https://api.reporter.nih.gov/v2/projects/search
